# %%
#Comentario de uma linha, tudo que estiver a frente da cerquilha será ignorado
print("Bom dia! Hoje é um excelente dia para aprender Python")
print("")
print("")
print("Aprendendo como utilizar comentários.")
print("segunda linha")
print("terceira linha")  #aqui é um comentário que não será interpretado
print("Hoje é um bom dia para aprender Python")
# Out:
# Bom dia! Hoje é um excelente dia para aprender Python
#
#
# Aprendendo como utilizar comentários.
# segunda linha
# terceira linha
# Hoje é um bom dia para aprender Python
