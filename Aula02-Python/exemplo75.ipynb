# %% [markdown]
# <h1> Aula 07 </h1>

# %%
"""
dicionario = {'1ra_chave':'1ro_valor’, '2a_chave':’2do_valor}
Chave = Nome
Valor = Telefone 
"""

retornar_ligacao = {
    		       "Andre": "(11) 3030-1122",
   		           "Carlos": "(11) 33547877",
                   "Ana": "(11) 3338-1245",
                   "Timoteo": "(11) 3645-8899"
                    }

print("Ligações pendentes", retornar_ligacao)

for nome in retornar_ligacao:
    print("Listagem de nomes do dicionario retornar Ligação = ", nome)

print()
# Out:
# Ligações pendentes {'Andre': '(11) 3030-1122', 'Carlos': '(11) 33547877', 'Ana': '(11) 3338-1245', 'Timoteo': '(11) 3645-8899'}
# Listagem de nomes do dicionario retornar Ligação =  Andre
# Listagem de nomes do dicionario retornar Ligação =  Carlos
# Listagem de nomes do dicionario retornar Ligação =  Ana
# Listagem de nomes do dicionario retornar Ligação =  Timoteo

# %%
for telefone in retornar_ligacao.values():
    print("Listagem dos numeros do dicionario retornar Ligação = ", telefone)

print()

print("Lista atualizada: Ligações pendentes", retornar_ligacao) 

retornar_ligacao.popitem() # Exclui o ultimo par (chave/valor) do dicionario ("Ana": 33381245)
print("Lista atualizada: Ligações pendentes", retornar_ligacao)
# Out:
# Listagem dos numeros do dicionario retornar Ligação =  (11) 3030-1122
# Listagem dos numeros do dicionario retornar Ligação =  (11) 33547877
# Listagem dos numeros do dicionario retornar Ligação =  (11) 3338-1245
# Listagem dos numeros do dicionario retornar Ligação =  (11) 3645-8899
#
# Lista atualizada: Ligações pendentes {'Andre': '(11) 3030-1122', 'Carlos': '(11) 33547877', 'Ana': '(11) 3338-1245', 'Timoteo': '(11) 3645-8899'}
# Lista atualizada: Ligações pendentes {'Andre': '(11) 3030-1122', 'Carlos': '(11) 33547877', 'Ana': '(11) 3338-1245'}

# %%
print("Ligações pendentes", retornar_ligacao) 

for pessoa in retornar_ligacao.keys():
    print("Listagem das pessoas (chaves)  do dic retornar_ligacao = ", pessoa)

print(" Lista das pessoas (chaves): ", list(retornar_ligacao.keys()))
print(" Lista : ", list(retornar_ligacao.keys()))
print()    

for telefone in retornar_ligacao.values():
    print("Listagem dos telefones (valores)  do dic retornar_ligacao =", telefone) 
print()
print(" Lista dos telefones: ", list(retornar_ligacao.values()))

retornar_ligacao.popitem() # Exclui o ultimo par (chave/valor) do dicionario ("Timoteo": 36458899)
# Out:
# Ligações pendentes {'Andre': '(11) 3030-1122', 'Carlos': '(11) 33547877'}
# Listagem das pessoas (chaves)  do dic retornar_ligacao =  Andre
# Listagem das pessoas (chaves)  do dic retornar_ligacao =  Carlos
#  Lista das pessoas (chaves):  ['Andre', 'Carlos']
#  Lista :  ['Andre', 'Carlos']
#
# Listagem dos telefones (valores)  do dic retornar_ligacao = (11) 3030-1122
# Listagem dos telefones (valores)  do dic retornar_ligacao = (11) 33547877
#
#  Lista dos telefones:  ['(11) 3030-1122', '(11) 33547877']
# ('Carlos', '(11) 33547877')
